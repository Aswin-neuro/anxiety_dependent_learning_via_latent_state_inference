# %% [markdown]
# # 1_maximum_likelihood_estimation_coin_toss
#
# Introductory notebook demonstrating EM for a two-coin toy example.
# Run this notebook to build intuition before proceeding to the simulations.
