# %% [markdown]
# # 2_gng_simulation_and_parameter_recovery
#
# Simulate RL agents performing the Go/No-Go task and run parameter recovery.
# This is a placeholder notebook — run and fill in the code cells as described in README.
